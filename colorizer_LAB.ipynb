# %%
# !unzip train.zip

# %%
import numpy as np
import keras

# %%
# load sample images from directory

def load_images(dir_path, color_info):

  from keras.utils import image_dataset_from_directory

  dataset = image_dataset_from_directory(
      directory = dir_path, labels=None,
      color_mode = color_info, image_size=(256, 256)
  )
  return dataset

# %%
dataset = load_images('train', 'rgb')
# Out:
# Found 245 files.

# %%
# convert tf dataset into numpy array
def tfdata_to_numpy(dataset):
  numpy_data = []
  for batch in dataset:
      numpy_data.append(batch.numpy())
  return np.concatenate(numpy_data, axis=0)

# %%
color_images = tfdata_to_numpy(dataset)
color_images.shape
# Out:
# (245, 256, 256, 3)

# %%
# plot given sample of images

def plot_images(images, color_mode='viridis'):
  import matplotlib.pyplot as plt

  n = len(images)
  plt.figure(figsize=(15, 15))
  for k in range(n):
    plt.subplot(1, n, k+1)
    plt.imshow(images[k], cmap=color_mode)
    plt.xticks([])
    plt.yticks([])

# %%
def preprocess_images(images):
  images = images.astype('float32') / 255.0
  return images

# %%
color_images = preprocess_images(color_images)

# %%
plot_images(color_images[:5])

# %%
# convert RGB images to LAB

def rgb_to_lab(rgb_images):

  from skimage import color
  image_lab = color.rgb2lab(rgb_images)
  L = image_lab[:, :, :, 0] / 100.0
  AB = image_lab[:, :, :, 1:] / 128.0
  return L, AB

# %%
train_l, train_ab = rgb_to_lab(color_images)
train_l.shape
train_ab.shape
# Out:
# (245, 256, 256, 2)

# %%
plot_images(train_l[:5], 'gray')

# %%
plot_images(train_ab[:5, :, : , 0], color_mode='coolwarm')

# %%
# build neural network to colorize grayscale images

from keras import layers

inputs = keras.Input(shape=(256, 256, 1))

# encoder layers
conv1 = layers.Conv2D(32, 3, activation='relu', padding='same', strides=2)(inputs)
conv2 = layers.Conv2D(64, 3, activation='relu', padding='same', strides=2)(conv1)

# bottleneck or latent layer
latent_layer = layers.Conv2D(128, 3, activation='relu', padding='same', strides=2)(conv2)

# decoder layers
up1 = layers.UpSampling2D((2,2))(latent_layer)
concat1 = layers.Concatenate()([up1, conv2])
dec1 = layers.Conv2D(64, 3, activation='relu', padding='same')(concat1)

up2 = layers.UpSampling2D((2,2))(dec1)
concat2 = layers.Concatenate()([up2, conv1])
dec2 = layers.Conv2D(32, 3, activation='relu', padding='same')(concat2)

up3 = layers.UpSampling2D((2,2))(dec2)
dec3 = layers.Conv2D(2, 3, activation='tanh', padding='same')(up3)

colorizer = keras.Model(inputs=inputs, outputs=dec3)
colorizer.summary()
# Out:
# Model: "functional"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ input_layer         │ (None, 256, 256,  │          0 │ -                 │
# │ (InputLayer)        │ 1)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d (Conv2D)     │ (None, 128, 128,  │        320 │ input_layer[0][0] │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_1 (Conv2D)   │ (None, 64, 64,    │     18,496 │ conv2d[0][0]      │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_2 (Conv2D)   │ (None, 32, 32,    │     73,856 │ conv2d_1[0][0]    │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ up_sampling2d       │ (None, 64, 64,    │          0 │ conv2d_2[0][0]    │
# │ (UpSampling2D)      │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate         │ (None, 64, 64,    │          0 │ up_sampling2d[0]… │
# │ (Concatenate)       │ 192)              │            │ conv2d_1[0][0]    │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_3 (Conv2D)   │ (None, 64, 64,    │    110,656 │ concatenate[0][0] │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ up_sampling2d_1     │ (None, 128, 128,  │          0 │ conv2d_3[0][0]    │
# │ (UpSampling2D)      │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_1       │ (None, 128, 128,  │          0 │ up_sampling2d_1[… │
# │ (Concatenate)       │ 96)               │            │ conv2d[0][0]      │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_4 (Conv2D)   │ (None, 128, 128,  │     27,680 │ concatenate_1[0]… │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ up_sampling2d_2     │ (None, 256, 256,  │          0 │ conv2d_4[0][0]    │
# │ (UpSampling2D)      │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_5 (Conv2D)   │ (None, 256, 256,  │        578 │ up_sampling2d_2[… │
# │                     │ 2)                │            │                   │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 231,586 (904.63 KB)
#  Trainable params: 231,586 (904.63 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
# train model on Luminance (L) as input
# and corresponding AB components as output

colorizer.compile(loss='mse', optimizer='adam', metrics=(['accuracy']))
colorizer.fit(train_l, train_ab, epochs=30, validation_split=0.2)
# Out:
# Epoch 1/30
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 68s 9s/step - accuracy: 0.5750 - loss: 0.0315 - val_accuracy: 0.6352 - val_loss: 0.0254
# Epoch 2/30
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 65s 9s/step - accuracy: 0.6279 - loss: 0.0268 - val_accuracy: 0.6369 - val_loss: 0.0251
# Epoch 3/30
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 71s 10s/step - accuracy: 0.6307 - loss: 0.0270 - val_accuracy: 0.6480 - val_loss: 0.0259
# Epoch 4/30
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 78s 9s/step - accuracy: 0.6422 - loss: 0.0264 - val_accuracy: 0.6415 - val_loss: 0.0246
# Epoch 5/30
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 65s 9s/step - accuracy: 0.6402 - loss: 0.0239 - val_accuracy: 0.6457 - val_loss: 0.0239
# Epoch 6/30
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 81s 9s/step - accuracy: 0.6439 - loss: 0.0257 - val_accuracy: 0.6564 - val_loss: 0.0239
# Epoch 7/30
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 83s 9s/step - accuracy: 0.6576 - loss: 0.0247 - val_accuracy: 0.6505 - val_loss: 0.0234
# Epoch 8/30
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 80s 9s/step - accuracy: 0.6538 - loss: 0.0238 - val_accuracy: 0.6790 - val_loss: 0.0232
# Epoch 9/30
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 68s 9s/step - accuracy: 0.6596 - loss: 0.0228 - val_accuracy: 0.6576 - val_loss: 0.0222
# Epoch 10/30
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 70s 10s/step - accuracy: 0.6539 - loss: 0.0237 - val_accuracy: 0.6760 - val_loss: 0.0213
# Epoch 11/30
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 81s 10s/step - accuracy: 0.6557 - loss: 0.0241 - val_accuracy: 0.6727 - val_loss: 0.0214
# Epoch 12/30
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 70s 9s/step - accuracy: 0.6725 - loss: 0.0220 - val_accuracy: 0.6746 - val_loss: 0.0210
# Epoch 13/30
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 64s 9s/step - accuracy: 0.6664 - loss: 0.0237 - val_accuracy: 0.6681 - val_loss: 0.0215
# Epoch 14/30
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 87s 10s/step - accuracy: 0.6819 - loss: 0.0227 - val_accuracy: 0.6934 - val_loss: 0.0212
# Epoch 15/30
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 82s 10s/step - accuracy: 0.6923 - loss: 0.0238 - val_accuracy: 0.7085 - val_loss: 0.0214
# Epoch 16/30
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 64s 9s/step - accuracy: 0.6623 - loss: 0.0225 - val_accuracy: 0.6682 - val_loss: 0.0205
# Epoch 17/30
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 63s 9s/step - accuracy: 0.6599 - loss: 0.0231 - val_accuracy: 0.7052 - val_loss: 0.0201
# Epoch 18/30
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 65s 9s/step - accuracy: 0.6869 - loss: 0.0217 - val_accuracy: 0.6889 - val_loss: 0.0206
# Epoch 19/30
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 83s 9s/step - accuracy: 0.6724 - loss: 0.0221 - val_accuracy: 0.6943 - val_loss: 0.0199
# Epoch 20/30
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 78s 11s/step - accuracy: 0.6911 - loss: 0.0225 - val_accuracy: 0.7056 - val_loss: 0.0199
# Epoch 21/30
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 66s 9s/step - accuracy: 0.6869 - loss: 0.0210 - val_accuracy: 0.6899 - val_loss: 0.0207
# Epoch 22/30
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 69s 10s/step - accuracy: 0.6827 - loss: 0.0214 - val_accuracy: 0.7091 - val_loss: 0.0197
# Epoch 23/30
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 69s 10s/step - accuracy: 0.6921 - loss: 0.0212 - val_accuracy: 0.7110 - val_loss: 0.0198
# Epoch 24/30
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 70s 10s/step - accuracy: 0.6883 - loss: 0.0217 - val_accuracy: 0.7145 - val_loss: 0.0202
# Epoch 25/30
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 70s 10s/step - accuracy: 0.6911 - loss: 0.0227 - val_accuracy: 0.7045 - val_loss: 0.0203
# Epoch 26/30
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 77s 9s/step - accuracy: 0.6935 - loss: 0.0207 - val_accuracy: 0.7103 - val_loss: 0.0193
# Epoch 27/30
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 87s 10s/step - accuracy: 0.6991 - loss: 0.0212 - val_accuracy: 0.7160 - val_loss: 0.0195
# Epoch 28/30
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 79s 12s/step - accuracy: 0.6886 - loss: 0.0209 - val_accuracy: 0.6881 - val_loss: 0.0218
# Epoch 29/30
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 69s 9s/step - accuracy: 0.6794 - loss: 0.0216 - val_accuracy: 0.7059 - val_loss: 0.0202
# Epoch 30/30
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 80s 9s/step - accuracy: 0.6704 - loss: 0.0220 - val_accuracy: 0.7070 - val_loss: 0.0198

# %%
# !unzip test.zip

# %%
# load test images
from keras.utils import load_img

test_sample = []
n = 10

for k in range(n):
    img_file = "test/" + str(k+1) + ".jpg"
    test_img = load_img(img_file, target_size=(256, 256))
    test_sample.append(test_img)

np.array(test_sample).shape
# Out:
# (10, 256, 256, 3)

# %%
plot_images(test_sample)

# %%
test_sample = preprocess_images(np.array(test_sample))
test_l, test_ab = rgb_to_lab(test_sample)
test_ab.shape
# Out:
# (10, 256, 256, 2)

# %%
plot_images(test_l, 'gray')

# %%
# convert LAB images to RGB
def lab_to_rgb(L, AB):

  rgb_images = []
  from skimage import color
  for k in range(len(L)):

    image_lab = np.zeros((256, 256, 3))
    image_lab[:, :, 0] = L[k] * 100
    image_lab[:, :, 1:] = AB[k] * 128

    image_rgb = color.lab2rgb(image_lab)
    rgb_images.append(image_rgb)
  return np.array(rgb_images)

# %%
# test conversion process from LAB to RGB
test_rgb = lab_to_rgb(test_l, test_ab)
plot_images(test_rgb)

# %%
# pass L to colorizer model to get A B
y_ab = colorizer.predict(test_l)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 946ms/step

# %%
# use predicted AB parameters to reconstruct RGB
y = lab_to_rgb(test_l, y_ab)
plot_images(y)

# %%
plot_images(y[:5, :, :, :])
